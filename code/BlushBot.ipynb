# %% [markdown]
# # **BlushBot: Personalized Skincare Recommendation System**
#
# ---
#
# ### **Introduction**
#
# In a world where skincare is deeply personal, finding the right product tailored to your specific needs can be a daunting task. BlushBot is here to revolutionize the way we shop for skincare by providing personalized product recommendations designed specifically for Indian customers.
#
# BlushBot leverages cutting-edge machine learning techniques such as **content-based filtering**, **TF-IDF vectorization**, and **cosine similarity** to match users' unique preferences with the most suitable skincare products. Whether you have oily skin, dry skin, or a specific concern like hydration or anti-aging, BlushBot ensures that you always get the best recommendations.
#
# ---
#
# ### **Why BlushBot?**
#
# - **Personalized Recommendations**: Designed for Indian customers, BlushBot understands your unique skincare needs.
# - **Smart Filtering**: Enter your **skin type**, **concern**, and **price range**, and let the system do the magic!
# - **Trusted by Science**: Uses state-of-the-art algorithms to ensure precise and accurate matches.
# - **Simplifying Choices**: With BlushBot, say goodbye to overwhelming product lists and hello to tailored recommendations.
# ---
#
# ### **Project Highlights**
#
# - **Categories Covered**:
#   - Moisturizers, Serums, Sunscreens, Toners, and Cleansers.
# - **Customer-Centric Features**:
#   - Recommendations based on **skin type**, **price**, and **concerns** like hydration or anti-aging.
# - **Local Relevance**:
#   - Focuses on Indian brands to meet the preferences of Indian customers.
# - **Technology Stack**:
#   - Built using Python, pandas, scikit-learn, and Streamlit for deployment.
#
# ---
#
# BlushBot doesn’t just recommend, it empowers users to make informed skincare choices tailored to their unique needs. Let’s dive into how it works!

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics.pairwise import cosine_similarity

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = pd.read_excel('/content/drive/MyDrive/BlushBot/datasets/combined_skincare_dataset.xlsx')

# %%
data = pd.read_excel('/content/drive/MyDrive/BlushBot/datasets/combined_skincare_dataset.xlsx')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 663 entries, 0 to 662
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   product_brand     663 non-null    object
#  1   product_name      663 non-null    object
#  2   product_category  663 non-null    object
#  3   quantity          663 non-null    object
#  4   price             663 non-null    int64
#  5   overall_rating    663 non-null    float64
#  6   no_of_ratings     663 non-null    int64
#  7   concern           663 non-null    object
#  8   ingredient        663 non-null    object
#  9   skin_type         663 non-null    object
#  10  star_5            663 non-null    int64
#  11  star_4            660 non-null    float64
#  12  star_3            628 non-null    float64
#  13  star_2            591 non-null    float64
#  14  star_1            629 non-null    float64
# dtypes: float64(5), int64(3), object(7)
# memory usage: 77.8+ KB

# %%
df = pd.read_excel('/content/drive/MyDrive/BlushBot/datasets/combined_skincare_dataset.xlsx')

# %% [markdown]
# The dataset used in BlushBot contains information about various skincare products, categorized into the following columns:
#
# ### **Columns in the Dataset**
# 1. **product_brand**: The name of the skincare brand.
# 2. **product_name**: The name of the skincare product.
# 2. **product_category**: Type of product (e.g., Moisturizer, Serum, Cleanser).
# 4. **skin_type**: Targeted skin type (e.g., Oily, Dry, Sensitive).
# 5. **price**: The product's price in Indian Rupees (INR).
# 6. **overall_rating**: Average customer rating for the product.
# 7. **Star Ratings**:
#    - **star_5**: Number of 5-star ratings.
#    - **star_4**, **star_3**, etc.
# 8. **concern**: The primary skin concern addressed by the product (e.g., Hydration, Anti-aging).
# 9. **ingredient**: Key active ingredients in the product.
# 10. **quantity**: Quantity of the skinare product in ML.
# 11. **no_of_ratings**: Total star ratings including star_5, star_4 and so on.

# %%
data.shape
# Out:
# (663, 15)

# %%
# Create a mapping of product names to indices
product_indices = pd.Series(data.index, index=data['product_name']).to_dict()

# Create a reverse mapping of indices to product names
index_to_product = pd.Series(data['product_name'].values, index=data.index).to_dict()
index_to_product
# Out:
# {0: 'Gentle Skin Cleanser',
#  1: 'Set of 6 Gulabari Rose Glow Face Cleanser Spray',
#  2: 'Gulabari Set Of 3 Rose Glow Face Cleanser For Balanced & Hydrated Skin',
#  3: '2% Niacinamide Non-Irritant & Soap Free Oily Skin Cleanser',
#  4: '2% Niacinamide Gentle Skin Cleanser for Sensitive, Dry, Normal Skin',
#  5: 'Watermelon SuperGlow Facial Gel Cleanser with Vitamin C & Cucumber',
#  6: 'The Daily Duet Gentle Hydrating Cleanser',
#  7: 'Salicylic Acid Jamun Face Wash Cleanser Gel For Active Acne',
#  8: 'Purify & Glow Cleanser + Mask For Deep Cleanses Pores',
#  9: 'Deep Pore Clean Milky Foam Face Wash Cleanser with Seaweed',
#  10: 'Coffee Face Wash for Fresh & Glowing Skin,Hydrate Cleanser for Oil Removal',
#  11: 'Luminous Brightening Foaming Cleanser & Face Wash For Clear & Even Skin',
#  12: 'Regenerist Cleanser & Face Wash for Plump & Bouncy Skin With Salicylic Acid',
#  13: 'Creamy Cleanser',
#  14: 'Red Vine Face Wash Cleanser for Anti Ageing & De-Pigmentation',
#  15: 'Acne Control Face Cleanser for Oily & Acne Prone with Salicylic Acid',
#  16: 'Vitamin C Green Tea Face Wash with Hyaluronic Acid Dirt Removal Cleanser',
#  17: 'Total Effects Foaming Cleanser & Face Wash To Fight 7 Signs of Ageing',
#  18: 'Jeju Aloe Fresh Soothing Gel to Foam Cleanser',
#  19: 'Clarifying Acne Cleanser with Zinc PCA & Salicylic Acid',
#  20: 'Deep Clean Facial Cleanser for Normal to Oily Skin',
#  21: 'Deep Clean Foaming Cleanser',
#  22: 'Luminous Brightening Foaming Cleanser & Regenerist Retinol 24 Night Moisturizer',
#  23: 'Low pH Good Morning Gel Cleanser',
#  24: 'Cica & Ceramide Gentle Cleanser with Aloe Vera Extracts',
#  25: 'Rice Water Brightening Daily Cleanser To Brighten Skin & Reduces Dark Spots',
#  26: 'D-Tan Facial Cleanser',
#  27: 'Snail Magic Barrier Repair Cleanser with Snail Mucin Concentrate',
#  28: 'Set Of 4 Face Cleanser Face Pack Face Scrub & Face Wash D-Tan Skin',
#  29: 'Vitamin C Face Wash with Turmeric & Foaming Silicone Cleanser Brush',
#  30: 'Ratrani Moroccan Lava Cleanser',
#  31: 'Coffee Face Wash for Glowing Skin,Hydrating Cleanser for Oil Removal',
#  32: '12 Organic Ingredients Face Brightening Daily Cleanser',
#  33: 'Clear Skin Exfoliating Cleanser',
#  34: 'Detan+ Mousse Hydrating Foam Cleanser',
#  35: 'Gentle Black Korean Facial Cleanser Hydrating Face Wash',
#  36: 'Radiance+ Mousse Hydrating Foam Cleanser',
#  37: 'Energising Water Gel Cleanser',
#  38: 'Facebath Deep Cleansing Milky Foaming Cleanser',
#  39: 'Clear Win Face Gel Cleanser with Salicylic Acid & Alpha Arbutin',
#  40: 'Kind To Skin Moisturising Facial Wash',
#  41: 'Oil Control Face Wash',
#  42: 'Bright Beauty Facewash with Niacinamide for Glass Skin-like Shine',
#  43: 'Foaming Face Wash for Oily Skin, Acne Prone Skin',
#  44: 'Gentle Cream Face Wash',
#  45: 'Rice Water Foaming Face Wash with In-Built Soft Face Brush',
#  46: 'Hydra Light Hyaluronic Acid Hydrating Gel Face Wash',
#  47: 'Deep Pore Cleansing Milk With Aloevera Rose For Skin',
#  48: 'Bright Beauty Facewash with Niacinamide for Glass Skin-like Shine',
#  49: 'Green Tea Tatva Scrub Cleanser',
#  50: 'Skarfix-TX Face Cleanser',
#  51: 'Set of 2 Ubtan Face Wash with Turmeric & Saffron',
#  52: 'Low pH Good Morning Gel Cleanser',
#  53: 'Brightening Beads Cleanser Gentle Exfoliation',
#  54: 'Daily Skin Detox Purifying Facial Wash',
#  55: 'Power Botanics Vitamin C Foaming Face Wash with in-built Face Brush',
#  56: 'Bright Beauty Vitamin C+E+A Infused Gel Face Wash For Brighter & Clearer Skin',
#  57: 'Collagen Face Cleanser Anti-Ageing',
#  58: 'Exfoliating FC-3 Face Cleanser AHA 10% + BHA 2% Face Wash',
#  59: 'Cleansers Clearing & Calming Acne Face Wash',
#  60: 'Set Of 2 Rice Face Wash With Rice Water & Niacinamide',
#  61: '2% Vitamin C Face Wash Foaming Cleanser with Brush',
#  62: 'Collagen Peptide Face Cream for Smooth & Plump Skin',
#  63: 'Papaya Foaming Face Wash with In-Built Soft Face Brush',
#  64: 'Ubtan Cleanser',
#  65: 'Age Protect Anti-Ageing Cream Reduces Wrinkles With Salicylic Acid & BHA',
#  66: 'Cucumber Mint Upvan Facial Cleanser',
#  67: 'Restore Hydrating Cream Cleanser',
#  68: 'Set of 2 Papaya Deep Cleanse Visibly Glowing Skin Face Wash',
#  69: 'Swiss Glacier Face Cleanser With Aloe Vera',
#  70: 'Papaya Deep Cleanse Visibily Glowing Skin Face Wash',
#  71: 'Fixderma Peelonate AHA Face Cleanser & Face Exfoliator',
#  72: 'Saffron & Honey Foaming Face Wash with In-Built Soft Face Brush',
#  73: 'Papaya Deep Cleanse Visibily Glowing Skin Face Wash',
#  74: 'Glow+ Mousse Hydrating Foam Cleanser with Papaya & Vitamin C',
#  75: 'Tatva Green Tea Face Wash',
#  76: 'Avocado Ceramide Cleanser-10% Vitamin C Serum-Guava Moisturizer',
#  77: 'Bioactive Niacinamide79 Face Cleanser',
#  78: 'Vitamin C Oil Free Face Wash For Acne-Prone Dry & Oily Skin',
#  79: 'Pack of 2 Lavender Charm Daily Ubtan Cleanser',
#  80: 'Blush & Glow Kiwi Gel Face Wash With 100% Real Kiwi Extract',
#  81: 'Aloe Vera Foaming Face Wash with In-Built Soft Face Brush',
#  82: 'Papaya Deep Cleanse Visibly Flawless Skin Face Wash',
#  83: 'Honey Gel Soothe & Nourish Foaming Face Wash To Target Dry Skin',
#  84: 'Upvan Cucumber Mint Face Wash',
#  85: "Lueur D'or Face Cleanser",
#  86: 'Natural Papain D10 Cleanser for Tan Removal & Uneven Skin Tone',
#  87: 'Blush & Glow Kiwi Gel Face Wash With 100% Real Kiwi Extract',
#  88: 'Fixderma Face21 Cleanser',
#  89: 'Unisex Bio Honey Gel Refreshing Foaming Face Wash',
#  90: 'Sustainable De Tan Cream Cleanser with Mint & Eucalyptus',
#  91: 'Blush & Glow Lemon Gel Face Wash 100% Real Lemon Extract',
#  92: '12 Organic Ingredients Face Brightening Daily Cleanser',
#  93: 'Sustainable Professional Phyto-Rx Whitening & Brightening Face Wash',
#  94: 'Set Of 4 Natural Cleansing Milk Enriched With Echinacea & Chamomile',
#  95: 'Bioactive Vitamin C30 Face Cleanser with Kakadu Plum & Rosehip',
#  96: 'Morning Nectar Moisturize & Nourish Face Wash',
#  97: 'Salicylic Acid Anti-Acne Foaming Face Cleanser',
#  98: 'Jeju Volcanic Oil Cleanser to Remove Makeup & Unclogs Pores',
#  99: 'Pearl Light Cleanser Vegan Face Wash to Remove Dark Spots',
#  100: 'Set of Vitamin C Face Serum & Face Wash',
#  101: 'Kind to Skin Set Of Refreshing Facial Wash 150ml & Micellar Cleansing Water',
#  102: 'Kumkumadi Face Cleanser',
#  103: 'Paris Glycolic Bright Daily Foaming Face Cleanser for Even Glowing Skin',
#  104: 'Gentle & Soft Deep Pore Cleanser',
#  105: 'Paris Revitalift Gel Cleanser for Fresh Hydrated & Youthful Skin',
#  106: 'Paris Revitalift Gel Cleanser for Fresh Hydrated & Youthful Skin',
#  107: '365 Foaming Cleanser- Lemon & Grapefruit',
#  108: 'Gentle Moisturizing Cleanser',
#  109: 'Fair Skin Anti Dust Facial Cleanser with Orange',
#  110: 'Doux Deep Cleanser Face Cleansing Lotion with Ceatyl Alcohol',
#  111: 'Sandal Cleansing Milk For Gentle Makeup Remover & Skin Nourishment',
#  112: 'Sandal Cleansing Milk For Deep Cleansing & Skin Soothing',
#  113: 'Kick-Start Face Cleanser with Salicylic Acid & Thymol T Essence',
#  114: 'Ultra Hydrating Pink Aloe Vera Non-drying Cleanser Face Wash',
#  115: 'Blue Light Defense Everyday Facial Cleanser',
#  116: 'Unisex Soft Light Moisturizing Non-Sticky Cream with Vitamin E & Jojoba Oil',
#  117: 'Ceramide & Vitamin C Oil-Free Moisturizer',
#  118: 'Barrier Repair Hydrating pH5.5 Face Cream with Ceramides & Hyaluronic',
#  119: 'Squalane Glow Moisturizer with Vitamin C & Niacinamide For Bright,Even-Toned Skin',
#  120: 'Paris Revitalift Anti-Wrinkles & Radiance SPF35 PA++ Moisturizing Day Cream',
#  121: 'WhiteGlow Vitamin C Radiance Creme with SPF20 for Dark Spots & Dull Skin',
#  122: 'Ceramides & Hyaluronic Barrier Repair Moisturizer with Rice Water',
#  123: 'CICA+5% Niacinamide Spot Reduction Oil-Free Moisturizer',
#  124: '5% Propylene Oil Free Moisturizer For Deep Hydration',
#  125: 'Honey & Almonds Deep Nourishing Skin Cream, Hands & Body',
#  126: 'Vitamin C+E Oil-Free Moisturizer For Glowing Skin & Fades Dark Spots',
#  127: '5 Barrier Hydra Gel Moisturizer With Ceramides & Avocado',
#  128: 'Total Effects Day Cream with SPF15',
#  129: 'Beetroot Hydraful Moisturizer with Hyaluronic Acid & Niacinamide',
#  130: 'Illuminate Oil-Free Day Moisturizer',
#  131: 'Skincare Strawberry Dew In The Spotlight Strobe Cream',
#  132: 'Unisex Anti-Wrinkle Cream',
#  133: 'Brightening Moisturizer-5% Niacinamide + 1% Kojic Acid + 5% Vitamin C',
#  134: 'Glow Hydra Gel Moisturizer With Vitamin C & Papaya',
#  135: 'Watermelon Oil-Free Matte Glow Lightweight Moisturizer with Glycolic',
#  136: 'Oil Free Moisturizer With Hyaluronic Acid',
#  137: '3% Vitamin E Moisturizer With Vitamin E & Lactic Acid For Dry & Flaky Skin',
#  138: 'Pomegranate Miracle Vitamin E Revitalizing Face Moisturizer SPF30',
#  139: 'Ceramide Supercream Hydrating Ceramide Rich Moisturizer',
#  140: 'Strawberry Dew Do-It-All Moisturizer',
#  141: 'Sunlit Gold Vitamin C + E In The Spotlight Strobe Cream',
#  142: 'White Lotus Day Cream SPF 50 with Hyaluronic Acid- Skin Brightening & Pigmentation',
#  143: '72Hr Hydrating Probiotics Oil-Free Gel Moisturizer with Hyaluronic Acid',
#  144: 'Swarn Kanti Fairness Cream with Gold & Fruits Extracts',
#  145: 'recommends Cica & Ceramide Oil-Free Moisturizer',
#  146: 'Natural Aura Glowing Radiance Day Cream with SPF15 with Vitamin B3, Pro B5 & E',
#  147: '92% Snail Mucin Collagen Boost Moisturizer',
#  148: 'Total Effects Day Cream with SPF15',
#  149: 'Vitamin C+E Oil-Free Moisturizer For Glowing Skin & Fades Dark Spots',
#  150: 'Skin Fruits Moisturizing Skin Cream for Healthy, Soft & Glowing Skin',
#  151: 'Niacinamide Face Cream for Clear & Even Skin',
#  152: 'The Oasis Skin Repair Cream with Olive Leaf Extract',
#  153: 'Water Boost Skin Quench Sleeping Creme for Dry Sensitive Skin with Pentavitin',
#  154: '5% Nia-Ceramide Mattifying Moisturizer for Oily & Acne Prone Skin',
#  155: 'Retinol24 Max Night Cream Reduces Fine Lines in 7 Nights',
#  156: 'Retinol Intense Repair Cream',
#  157: 'Total Effects Night Cream-Fights 7 Signs of Ageing With Glycerin',
#  158: 'Hydro Boost Nourishing Cream with Hyaluronic Acid',
#  159: '72Hr Hydrating Probiotics Oil-Free Gel Moisturizer with Hyaluronic Acid',
#  160: 'Rice Water Tone Up Face Cream With Niacinamide',
#  161: 'Super Light Gel Oil Free Moisturiser With Hyaluronic Acid + Vitamin E',
#  162: 'Swarn Kanti Fairness Cream with Gold & Fruits Extracts',
#  163: 'Peach Ceramide Moisturizer with SPF 24',
#  164: 'Peach Milk Soft Vit E Creme',
#  165: 'Wheatgerm Anti-Ageing Night Cream',
#  166: 'Perfect Radiance Brightening Day Cream with Sunscreen Protection',
#  167: 'Lumi Glow Cream Highlighting Face Moisturizer',
#  168: 'Oil-Free Gel Face Moisturizer',
#  169: '5% Nia-Ceramide Deep Moisturizing Cream with Oats Extract',
#  170: 'Vitamin C Skin Brightening Day Cream',
#  171: '5 Ceramides Barrier Repair Lightweight Moisturizer with Koeran CICA',
#  172: 'Cica + Niacinamide Oil-Free Face Moisturizer to Treat Acne',
#  173: 'Moisturising Cream',
#  174: 'Glycolic Illuminate Day Creme With Glycolic Acid For Radiant & Even Tone Skin',
#  175: 'Saundarya Anti Aging Cream for Wrinkles & Fine Lines',
#  176: 'Illuminate & Hydra Gel Moisturizer With Wild Berries',
#  177: 'Rice Water & Niacinamide Clear Moisture Gel Cream',
#  178: 'Lightweight & Non Greasy Moisturising Cream',
#  179: 'Red Vine Face Cream SPF 30 With Vitamin C & Rosehip Oil For Dark Spots & Ageing',
#  180: 'Vitamin C Brightening SPF 30 PA+++ Day Cream For Glowing Skin',
#  181: 'Skin Tint Moisturizer With SPF 15',
#  182: 'Snail Mucin Barrier Repair All-In-One Face Cream for Fine Lines',
#  183: 'Ceramide + HA Intense Moisturizer To Repair Dry & Dull Skin',
#  184: 'Fairy One Natural Glow Cream',
#  185: '4% Urea Deep Moisturizing Cream With Lactic Acid & Ceramide Complex',
#  186: 'Total Effects Day Cream',
#  187: 'Lightweight-Hydrating & Brightening Face Moisturizer for Normal To Dry Skin',
#  188: 'Radiance+ Oil Free Moisturizer with Watermelon & Niacinamide',
#  189: 'Barrier Care Cream with Ceramide & Peptide For Normal to Dry Skin',
#  190: 'Snail Mucin Moisturizer With Hyaluronic Acid',
#  191: 'Matcha Better Anti-Shine Face Moisturizer With Licorice Root & Cica',
#  192: 'Hydro Booster Gel With Hyaluronic Acid & Ceramide',
#  193: '100% Natural Salicylic Acid Liquid Moisturiser with Aloevera & Zinc PCA',
#  194: '1% Salicylic Acid Oil-free Moisturizer With Oat Extract For Active Acne',
#  195: 'Oil-Free Daily Face Moisturizer with Hyaluronic Acid & Ceramides',
#  196: 'Rose Gel Face Cream with Hyaluronic Acid for Oil-Free Non-Sticky Hydration',
#  197: 'Total Effects Day Cream Gentle with SPF 15 for Sensitive Skin',
#  198: 'Pore Minimizing Daily Face Moisturizer with 3% Niacinamide 3% PHA',
#  199: 'Vitamin C Liquid Moisturiser with Aloevera & Arbutin',
#  200: '24K Gold Lightweight Gel Face Moisturizer with Hyaluronic Acid & Alpha Arbutin',
#  201: 'Total Effects Day Cream',
#  202: 'Saffron & Kumkumadi Oil Glow Bright Moisturizer For Dull Skin With SPF 35',
#  203: 'Oil-Free SPF 15 Face Moisturizer',
#  204: 'Skin Soothe Moisturizer- 1% Ceramides + 0.2% Bisabolol',
#  205: 'Oil Control Face Moisturizer With Salicylic Acid',
#  206: 'Sustainable Naked & Raw Coffee Face Moisturizer',
#  207: 'Ceramide & Vitamin C Moisturizing Cream',
#  208: 'Turmeric Nutmeg All Day Face Malai For Pigmentation',
#  209: '5% Cica-Glow Daily Face Moisturizer with Alpha Arbutin & Tranexamic Acid',
#  210: 'Set Of 2 Vitamin C Daily Glow Face Cream For Skin Illumination',
#  211: 'Set Of 2 Pure Aloe Non Sticky Light Moisturiser Skin Cream For Hydration',
#  212: 'Snail Peptide 96 Advanced Moisturizing & Hydrating Cream',
#  213: 'Kesar & Kojic Daily Pigmentation Correction Cream',
#  214: 'Set Of 2 Hydra Fresh Ultra Light Gel Oil Free Moisturiser',
#  215: 'Dr. V Skin Renew Barrier Repair Peptide Moisturizer',
#  216: 'Vitamin C Face Cream With SPF 20 for Skin Illumination',
#  217: 'YouthRx SPF20 Firm & Bright Cream with Vitamin C',
#  218: 'Ceramide & Vitamin C Moisturizing Cream',
#  219: 'SKARFIX-TX 10% Tranexamic Acid + 2% Kojic Acid & Vitamin C Face Cream',
#  220: 'Long Lasting Intense Hydration Moisturizer with Goat Milk',
#  221: 'Set Of 2 Glow+ Oil Free Moisturizer With Papaya',
#  222: 'AYURVEDIC SAFFRON & PAPAYA Anti Wrinkle Cream',
#  223: 'Vitamin C Face Cream for Radiant Skin for All Skin Types',
#  224: 'Pigmentation Corrector Daily Cream With 2% Kojic Acid To Reduce Pigmentation',
#  225: '2% Kojic Acid 1% Niacinamide Anti-Pigmentation Cream',
#  226: 'Kashmiri Saffron Moisturizing Cream With Jasmine With SPF 25',
#  227: 'Vitamin E Intense Nourish Cream',
#  228: 'Kesar & Kojic Acid Moisturizing Cream',
#  229: 'Power Botanics Vitamin C Face Cream',
#  230: 'Skin Brightening Day Cream',
#  231: 'Advanced Snail 96 Mucin Power Essence with 96% Snail Mucin for All Skin Types',
#  232: 'Deconstruct Vitamin C Serum-10% Vitamin C + 0.5% Ferulic Acid',
#  233: 'Vitamin C 10% Face Serum for Glowing Skin',
#  234: 'Bright Complete 30X Vitamin C Face Serum',
#  235: '10% Niacinamide Face Serum with Zinc',
#  236: 'Set of 3 Saundarya Aloe Vera Gel for Pimples & Wrinkles',
#  237: 'Glycolic Acid-AHA, Salicylic Acid-BHA, PHA Face Exfoliator-Peeling Solution Serum',
#  238: 'Paris Revitalift 1.5% Hyaluronic Acid Serum for Hydrating & Plumping Skin',
#  239: '2% Salicylic Acid Serum (BHA)',
#  240: '2% Kojic Acid Face Serum With 1% Alpha Arbutin & Niacinamide',
#  241: 'Bright Beauty Anti-Pigmentation Serum with 12% Gluta-Niacinamide Complex',
#  242: 'Paris Revitalift Hyaluronic Acid Serum for Hydrating & Plumping Skin',
#  243: 'Bright Beauty Anti-Pigmentation Serum with 12% Gluta-Niacinamide Complex',
#  244: '10% Niacinamide Face Serum To Fade Acne Marks & Treat Dark Spots',
#  245: 'Absolute Perfect Radiance Brightening Face Serum with 98% Pure Niacinamide',
#  246: 'Regenerist Retinol 24 Night Serum-Fragrance-Free',
#  247: '10% Vitamin C Face Serum with 5% Niacinamide & Hyaluronic Acid',
#  248: '0.3% Retinol Anti Aging Night Serum',
#  249: 'Set of 3 Saundarya Aloe Vera Gel with Kesar Chandan',
#  250: '10% Vitamin C+E & 5% Niacinamide Glowing Face Serum to Fights Pigmentation',
#  251: 'Jamun Acne Spot Corrector Gel For Reducing Active Acne',
#  252: 'Clearing Serum- 2% Alpha Arbutin + 5% Niacinamide',
#  253: '10% Niacinamide Face Serum with Rice Water',
#  254: 'Snail 99 Mucin Serum For Intense Hydration',
#  255: '10% Niacinamide Face Serum with Rice Water',
#  256: 'Paris Glycolic Bright Skin Brightening Serum to Reduce Dark Spots',
#  257: '2% Salicylic Acid Face Serum with Witch Hazel & Willow Bark For Acne',
#  258: '5% Niacinamide Serum With Hyaluronic Acid',
#  259: '15% Vitamin C Glow Face Serum To Fight Dark Spots & Pigmentation',
#  260: 'Bright Healthy Radiance Perfecting Serum',
#  261: '10% Niacinamide Face Serum with Zinc To Fade Acne Marks & Dark Spots',
#  262: '2% Alpha Arbutin Serum With Hyaluronic Acid',
#  263: 'Green Tangerine Vita-C Dark Spot Care Serum',
#  264: '15% Vitamin C Glow Face Serum To Fight Dark Spots & Pigmentation',
#  265: 'PLIX Depigmentation Kit | With 2% Alpha Arbutin, SymWhite PLUS & 1% Niacinamide',
#  266: '2% Kojic Acid Face Serum with 1% Alpha Arbutin & Niacinamide',
#  267: '10% Vitamin C+E & 5% Niacinamide Glowing Face Serum',
#  268: 'Glow Serum With Propolis & Niacinamide',
#  269: '16% Vitamin C Face Serum with Vitamin E & Ferulic Acid for Brightening',
#  270: 'Vitamin C Brilliance Serum',
#  271: 'Paris Glycolic Bright Skin Brightening Serum to Reduce Dark Spots',
#  272: '2% Salicylic Acid Serum with Witch Hazel & Willow Bark',
#  273: '12% Niacinamide Azelaic Acid Clarifying Serum',
#  274: "Nature's Essence Moisturising Aloe Beauty Gel",
#  275: 'Absolute Youth Infinity Skin Sculpting Face Serum',
#  276: '10% Vitamin C Face Serum with 5% Niacinamide & Hyaluronic Acid',
#  277: 'Alpha Arbutin & Vitamin C Skin Brightening Face Serum For Dark Spot & Pigmentation',
#  278: '9 to 5 2% Active Vitamin C Face Serum for Bright Healthy Glowing Skin',
#  279: 'Hyaluronic Acid 2% Serum',
#  280: 'The Derma Co. 10% Niacinamide Face Serum For Acne Marks And Acne Prone Skin',
#  281: 'Retinol & Peptide Serum-0.2% Retinol + 1% Peptides',
#  282: 'Sali-Cinamide Anti-Acne Face Serum with 2% Salicylic Acid & 5% Niacinamide',
#  283: 'Professional Phyto Rx Whitening Brightening Serum',
#  284: 'Pore Minimizing Face Serum with 4% Niacinamide, 5% PHA and p-REFINYL(r)',
#  285: '3% Tranexamic Acid Serum with Peptides & Niacinamide for Hyperpigmentation',
#  286: 'Korean Glass Skin Freshly Juiced Vitamin C Drop Face Serum For Dark Spot',
#  287: 'Vitamin C Brillance Serum with 10% Vit C Complex',
#  288: "L'Oreal Paris Revitalift Crystal Micro-Essence Face Serum",
#  289: '10% Niacinamide Face Serum For Blemishes',
#  290: 'Cica Niacinamide Night Gel with Tea Tree Oil For Dark Spots & Acne',
#  291: 'Hydra Light Hyaluronic Acid Complex 2% Face Serum',
#  292: '5% Niacinamide Face Serum With Amino Acid To Fade Blemishes For Bright Skin',
#  293: '10% Niacinamide CICA Anti-Acne Glow Face Serum for Dark Spots & Acne Scars',
#  294: 'Aloe Vera Gel For Face with Pure Aloe Vera & Vitamin E for Skin and Hair',
#  295: 'Bright Complete Vitamin C Night Serum With 10% Vitamin C for Bright Skin',
#  296: '96% Snail Mucin Collagen Boost Serum-With Niacinamide',
#  297: '0.15% Encapsulated Anti Aging Retinol Night Serum',
#  298: 'Mandarin & 15% Vitamin C Glow Face Serum',
#  299: 'Vitamin C Brillance Serum with 10% Vit C Complex',
#  300: 'Vitamin C Daily Glow Face Serum For Oily Skin & Dark Spots',
#  301: 'Hyaluronic Dewy Face Serum with 10% Hyaluronic Acid & Pentavitin Complex',
#  302: 'Peach 70 Niacin Serum',
#  303: 'Aloe Vera Organic Gel with Vitamin E & Antiseptic Herbs',
#  304: 'Peach Milk Vit E Gel Moisturizer',
#  305: '15% Vitamin C Face Serum For Skin Brightening Dark Spots',
#  306: 'Snail Peptide 96 Hydrating Serum With Niacinamide',
#  307: 'WhiteGlow Anti-Pollution Vitamin C + Gold Radiance Face Serum',
#  308: 'Retinol24 Max Night Serum To Visibly Reduce Fine Lines',
#  309: 'Dew Drama 6% Vit E + B3 + F Serum with Pro-Ceramide',
#  310: 'Lumi-Smooth 8% AHA+ Face Serum with BHA',
#  311: 'Regenerist Micro Sculpting Serum with Hyaluronic Acid & Niacinamide',
#  312: 'Glycolic Illuminate Face Serum with 1% Glycolic Acid To Reduce Dullness',
#  313: 'Skin Naturals Bright Complete Vitamin C Serum Gel Moistuirser',
#  314: 'Revive Ginseng & Retinal Eye Serum',
#  315: '2% Kojic Acid Face Serum For Dark Spots & Pigmentation',
#  316: '2% Kojic Acid Cream for Pigmentation',
#  317: 'Dandelion Youth Anti-Ageing Serum',
#  318: 'Rice Water Dewy Active Serum With 10% Niacinamide',
#  319: 'Pore Control Serum',
#  320: 'Absolute Hyaluronic Dewy Overnight Gel',
#  321: 'Optimal Hydration 48H Activation Serum with Hyaluronic Acid',
#  322: 'Multi Peptides Anti Aging Night Serum',
#  323: 'First Spray Serum With White Truffle',
#  324: 'Korean Freshly Juiced Vitamin Drop Serum',
#  325: '99% Pure Aloe Vera Gel for Skin and Hair',
#  326: 'Women Absolute Argan Oil Radiance Oil-In Gel Face Cream',
#  327: 'C-Glow Serum For Dark Spots',
#  328: '10% Niacinamide Face Serum with Zinc PCA & White Lotus',
#  329: 'Bright Beauty 12% Vitamin C+E+A Complex Face Serum For Brighter & Clearer Skin',
#  330: 'Unisex 15% AHA + 1% BHA Beginner Face Peeling Solution',
#  331: 'Age Protection Set Of 2 Vitamin C Serum & Retinol Night Serum',
#  332: 'Bright Complete Vitamin C Night Serum With 10% Vitamin C for Bright Skin',
#  333: '24K Gold Serum with Niacinamide & Hyaluronic Acid',
#  334: 'Niacinamide Vitamin B3-20% Face Serum',
#  335: "L'Oreal Paris Women Revitalift Crystal Micro-Essence Serum",
#  336: 'Super Bright C16 Vitamin C Face Serum With Niacinamide For Pigmentation',
#  337: 'Vitamin C Face Serum For Bright, Glowing Skin',
#  338: 'The Vitamin C 23 Serum with Hyaluronic Acid & Allantoin',
#  339: '5% Niacinamide Skin Clarifying Face Serum for Clear & Glowing Skin',
#  340: 'Clear Face Care Gel for Acne-Prone Skin',
#  341: 'The Gamechanger Satin-Matte Niacinamide Face Serum With Niacinamide',
#  342: 'Vitamin C Daily Glow Face Serum For Oily Skin & Dark Spots',
#  343: '9 to 5 Naturale Aloe Aqua Gel',
#  344: 'Collagen Peptide Face Serum for Smooth & Plump Skin With Niacinamide',
#  345: 'Absolute Youth Infinity Face Serum with 89% Pure Pro Retinol C Complex',
#  346: 'Hyaluronic Dewy Micro Essence with 4% Hyaluronic Acid',
#  347: 'Even Better Clinical Radical Dark Spot Corrector + Interrupter 30 ml',
#  348: '10% Niacinamide Face Serum with Zinc PCA & White Lotus',
#  349: 'Dark Spot Clearing Turmeric Face Serum',
#  350: 'Salicylic Acid & Niacinamide Oil Control Serum for Blackheads & Acne',
#  351: '6 Peptide Complex Collagen Boosting & Firming Essence',
#  352: 'Overnight Acne Spot Corrector',
#  353: '2% Salicylic Acid Serum With Witch Hazel',
#  354: 'Set of 2 Vitamin C Face Serum with Hyaluronic Acid',
#  355: '15% Vitamin C Face Serum with Ferulic Acid & Kakadu Plum',
#  356: 'Retinol & Hyaluronic Acid 1% Lift & Firm Serum for Anti Aging',
#  357: '10% Niacinamide CICA Anti-Acne Glow Face Serum for Dark Spots & Acne Scars',
#  358: 'Glow Serum With Hyaluronic Acid & Kakadu Plum Fruit Extract',
#  359: 'Skarfix-TX De-Pigmentation & Brightening Face Serum',
#  360: 'thinkDERMA 2% Salicylic Acid Face Serum for Active Acne',
#  361: 'No.5 Goodbye Blemish Serum',
#  362: 'Hydro Boost Hyaluronic Acid Face Serum with Pro-Vitamin B5',
#  363: 'Tran-Zelaic Pigmentation Corrector Serum',
#  364: 'Retinol Cica Repair Ampoule',
#  365: 'Advanced Snail Radiance Dual Essence with Niacinamide',
#  366: '2% Salicylic Acid Face Serum with Glycolic Acid & White Lotus',
#  367: "L'Oreal Paris Women Revitalift Crystal Micro-Essence Face Serum",
#  368: 'Lightweight Gel Sunscreen-SPF 55+ PA+++',
#  369: 'UltraSheer Dry Touch Sunblock Sunscreen SPF 50+ With Helioplex',
#  370: 'SPF 50 PA+++ Matte Sunscreen Niacinamide',
#  371: 'Vitamin C + E Sunscreen SPF 50 PA+++ For Glowing Skin, 100% No White Cast',
#  372: 'SPF 50 PA++++ Multi Vitamin Sunscreen',
#  373: 'Relief Sun',
#  374: 'Vitamin C + E Sunscreen SPF 50 PA+++ For Glowing Skin with No White Cast',
#  375: 'Matte Finish SPF 50 PA +++ Sun Expert Tinted Sunscreen',
#  376: 'UVA/B Protection Matte Sunscreen SPF 50 PA+++ with Niacinamide',
#  377: '1% Hyaluronic Sunscreen SPF 50 PA++++ Lightweight Aqua Gel',
#  378: 'Sun SPF50+ Light Gel with Vitamin E',
#  379: 'Watermelon Hyaluronic SPF 50 PA+++ Dewy & 100% No White Cast Sunscreen',
#  380: '1% Hyaluronic Sunscreen SPF50 Aqua Gel for Oily, Dry, Acne-Prone Skin',
#  381: 'Glow+ Dewy SPF 50 PA+++ Sunscreen With UVA/B & Blue Light Protection',
#  382: '1% Hyaluronic Sunscreen Aqua Ultra Light Gel With UVA & B Protection',
#  383: 'Radiance+ SPF50 PA+++ Dewy Sunscreen with Watermelon & Niacinamide',
#  384: 'Detan+ Dewy Lightweight No White Cast Sunscreen with SPF 50+ & PA++++',
#  385: 'Anti-Acne Oil Free SPF 40+ & PA+++ Sunscreen Gel',
#  386: 'Sun Expert Tinted Sunscreen SPF 50 PA +++',
#  387: 'UltraSheer Dry Touch Sunblock',
#  388: 'Ceramide & Vitamin C SPF 50+ Sunscreen',
#  389: 'SPF 30+ AC Moisturizer with Sunscreen',
#  390: "POND'S Age Miracle Wrinkle Corrector SPF 18 PA++ Day Cream",
#  391: 'Sun Expert SPF 25 PA++ Lightweight & Non Sticky Super Matte Lotion Sunscreen',
#  392: '2% Niacinamide Sunscreen SPF 50 PA+++ UVA/B To Reduces Tan',
#  393: 'Strawberry Dew Tinted Sunscreen SPF 50+ PA++++',
#  394: 'Glow+ Dewy Lightweight & Hydrating Sunscreen with SPF50 & PA+',
#  395: 'UV Screen SPF 50+ PA+++ UVA Safe Sun Matte Gel',
#  396: 'SPF 50++ Relief Sun Rice Probiotics',
#  397: 'SPF 30 PA++ UVA/B Protection Matte Sunscreen with Niacinamide',
#  398: 'Safe Sun UV Screen Matte Gel Sunscreen with SPF 50',
#  399: 'Sun SPF30 Light Gel with Vitamin E',
#  400: 'Safe Sun PA++ SPF 30 Sun Block Cream',
#  401: 'Blueberry Hydrate Barrier Repair Sunscreen SPF 50+ PA++++',
#  402: 'Super UV Invisible Serum Sunscreen SPF50 PA++++',
#  403: 'Niacinamide Oil Balance SPF50 Light & Matte Fluid Sunscreen with Oats',
#  404: 'Vitamin C & Niacinamide Essentials Brightening SPF 50 Sunscreen',
#  405: '9to5 Sun Expert Tinted Invisible Sunstick SPF 50 PA++++ with Shea Butter',
#  406: 'Cica Calming Niacinamide SPF50 PA+++ Sunscreen',
#  407: 'Safe Sun Sunscreen Breezy Berry',
#  408: '9to5 1% Niacinamide & Vit C Water-Light SPF 50 PA++++ Sunscreen Gel for 2X Glow',
#  409: 'Blueberry Hydrate Barrier Repair Sunscreen SPF 50+ PA++++',
#  410: 'Sun Relief Set Of 2 Rice + Probiotics SPF 50+ PA++++',
#  411: 'SPF 50 PA+++ Sunscreen Gel with Niacinamide, Water Light, No White Cast',
#  412: 'SPF 55 PA++ UVA UVB Serum Boost Sunscreen with Niacinamide C',
#  413: 'Sun Shield Sandalwood 50+SPF UVA UVB Sunscreen Ultra Protective Lotion',
#  414: 'FISICO Matte Sunscreen Gel',
#  415: 'Light Fluid SPF 50 Face Sunscreen',
#  416: 'AC Moisturiser with Microencapsulated Sunscreen',
#  417: 'CICA Calming Matte Sunscreen SPF 50+ PA++++',
#  418: 'Safe Sun PA+++ SPF 40 Daily Sunblock',
#  419: 'Sunscreen Gel SPF 50 PA+++ with Niacinamide, Water-Light, No White Cast',
#  420: 'Strawberry Dew SPF 50+ Pa++++ Tinted Sunscreen',
#  421: 'Sun Safe 3-in-1 Matte-Look SPF 40 Daily Sunscreen',
#  422: 'Pack Of 2 1% Hyaluronic Sunscreen SPF 50 Aqua Gel, PA++++',
#  423: 'Set of 2 Glow+ SPF50 Dewy Sunscreen with Vitamin C & Papaya',
#  424: 'Safe Sun 3 in 1 Matte Look Daily Sunblock SPF 40 PA+++ Tinted Sunscreen',
#  425: 'Shadow Sunscreen SPF 50+ Gel For Oily Acne Prone Skin with PA+++ Protection',
#  426: 'All I Need Sunscreen SPF 50 PA ++++ with Ceramide For Moisturizing',
#  427: 'C-Cinamide Sunscreen SPF 50 PA+ Aqua Gel With Vitamin C & Niacinamide',
#  428: 'SPF 30 PA++ UVA/B Protection Matte Sunscreen with Niacinamide',
#  429: 'SPF50 PA+++ Pore Minimizing Priming Sunscreen with Niacinamide',
#  430: 'CoverUp Dewy Finish SPF 50+PA++++ Broad Spectrum Sunscreen with Niacinamide',
#  431: 'Pore Minimizing Priming Sunscreen SPF 50 & PA+++ For Open Pores',
#  432: 'SPF 50 PA++ UVA UVB Serum Boost Invisible Gel Sunscreen with Niacinamide C',
#  433: 'SPF 55 PA++ UVA UVB Serum Boost Sunscreen with Niacinamide C',
#  434: 'Ceramide & Vitamin C Sunscreen SPF 50+ PA+++',
#  435: 'Detan+ Dewy Sunscreen SPF 50 PA++++ With Cherry Tomato & Hyaluronic Acid',
#  436: 'Daily Multi-Function SPF 70+ Sunscreen',
#  437: 'CoverUp SPF 50+ PA++++ Broad Spectrum Matte Sunscreen with Niacinamide',
#  438: 'Unisex Glow Radiance Luminous Skin Protection Lotion',
#  439: 'Sun Expert SPF 25 PA++ Lightweight & Non Sticky Super Matte Lotion Sunscreen',
#  440: 'Hyaluronic Acid Watery Sun Gel SPF50+ PA++++',
#  441: 'Strawberry Dew Tinted Sunscreen SPF 50+',
#  442: 'Radiance+ Dewy Sunscreen with Watermelon & Niacinamide SPF50 PA+++',
#  443: 'Shadow Sunscreen SPF 30+ Gel For Oily Skin with PA+++ Protection',
#  444: 'Kesar & Kojic Acid Sunscreen SPF 50+ PA++++',
#  445: 'Shadow Sunscreen SPF 30+ Gel for Oily Skin with PA+++ Protection',
#  446: 'Illuminate+ Dewy Sunscreen SPF 50+ PA++++',
#  447: 'Shadow SPF 50+ UVA & UVB Protection Gel Sunscreen',
#  448: 'Paris UV Defender Serum Protector Bright & Clear Sunscreen SPF 50+',
#  449: 'SPF 50 PA+++ UVA UVB Protect & Brighten Serum Sunscreen with Niacinamide C',
#  450: 'Sun Shield Sandalwood 50+SPF Ultra Protective Sunscreen Cream',
#  451: 'Morning Nectar SunProtect 30+SPF UVA+UVB Visibly Flawless Skin Moisturizer',
#  452: '9to5 1% Hyaluronic Water-Light SPF 50 PA++++ Sunscreen Gel for Hydrated Skin',
#  453: 'Aloe Soothing Sun Cream SPF 50 PA+++',
#  454: 'Illuminate+ Dewy Sunscreen SPF 50+ PA++++',
#  455: 'Unisex Safe Sun SPF 50 UV Screen MatteGel Sunscreen',
#  456: 'Tone Up No Sebum Sunscreen SPF50+ PA++++',
#  457: 'Rice Water SPF50 PA+++ Dewy Sunscreen with Niacinamide',
#  458: 'Pore Minimizing SPF 70 Sunscreen with Multivitamins & Niacinamide',
#  459: 'Kesar & Kojic Acid Sunscreen SPF 50+ PA++++',
#  460: 'Unisex IR SPF 30+ & PA+++ Sunscreen Gel',
#  461: 'Shadow Sunscreen SPF 50+ Cream for Dry Skin with PA+++ Protection',
#  462: 'Lightweight Pollution Protect Mineral SPF 50 + PA+++ Sunscreen Gel',
#  463: 'Shadow Sunscreen SPF 50+ Cream For Dry Skin with PA+++ Protection',
#  464: 'Haldi & Hyaluronic Acid SPF50 Hydrating Sunscreen',
#  465: '1% Hyaluronic SPF 60 PA++++ Tinted Sunscreen Gel With No White Cast',
#  466: 'Hydrating Fluid Sunscreen SPF 60 PA++++ With UV Filter Zinc Oxide',
#  467: 'Wild Berries & Alpha Arbutin Illuminate+ Dewy Sunscreen SPF50+ PA++++',
#  468: 'Watery Sun Cream',
#  469: 'Mugwort + Camelia SPF50 PA++++ Matte Sun Stick',
#  470: 'Sun Miracle SPF 35 PA+++ Protect & Bright Light Sunscreen with Niacinamide',
#  471: '2% Niacinamide SPF50 PA+++ Glow Sunscreen with Spanish Squalane',
#  472: 'Sun Expert SPF50 PA+++ Face Primer + Sunscreen',
#  473: 'Ultra Light Invisible Sunscreen SPF50++++',
#  474: 'Set Of 2 CoverUp Broad Spectrum Sunscreen SPF & Vitamin C Serum',
#  475: 'SPF 50+ PA++++ Sunscreen With Avocado For Glowing Skin',
#  476: 'Vitamin C Daily Glow SPF50 PA+++ Sunscreen with Turmeric',
#  477: 'Glow+ Dewy Sunscreen SPF 50 PA++++',
#  478: 'Safe Sun Vitamin-C MatteGEL SPF50 Daily Sunscreen',
#  479: 'Sun Moisturising Sun Lotion SPF 50 PA ++ with Vitamin E',
#  480: 'SPF 50 PA++ UVA UVB Serum Boost Invisible Gel Sunscreen with Niacinamide C',
#  481: 'Sun Shine Control UV Face SPF50 Sun Screen',
#  482: 'Centella & Niacinamide SPF50 Sunscreen for Oil & Acne Control',
#  483: 'Vitamin C Pure Glow Milk SPF50 Ultralight Sunscreen with Kojic Acid',
#  484: 'Niacinamide Sunscreen SPF 50 with Water Resistant & No White Cast',
#  485: '1% Hyaluronic Long Lasting SPF50 PA++++ Sunscreen with Vitamin E',
#  486: 'UV Doux Mineral Sunscreen Gel SPF 50 PA+++',
#  487: 'Hyaluronic Sunscreen Stick With SPF 60 & PA++++',
#  488: 'Ultra Light SPF50 PA++++ Water Sunscreen with Aloe & Hyaluronic Acid',
#  489: 'Ceramide & Vitamin C Sunscreen SPF 50+ PA+++',
#  490: 'Haldi & Hyaluronic Acid Sunscreen',
#  491: 'Paris UV Defender Serum Protector Matte & Fresh Sunscreen SPF 50+',
#  492: 'Safe Sun PA+UVA SPF20 Sunscreen',
#  493: 'Aqua Surge Clear Sunstick SPF 60',
#  494: 'Set Of 2 Glow+ Dewy Papaya Vit-C Sunscreen SPF50+ PA++++',
#  495: 'Unisex Ultra Matte Sunscreen Gel with SPF 60',
#  496: 'Chamomile & White Tea Sheer Matte Lightweight SPF 50 PA+++ Day Cream',
#  497: 'Lite SPF 50+ & PA+++ Anti-Tanning Sunscreen Gel',
#  498: 'Sun Shield Sandalwood 50+SPF Ultra Protective Sunscreen Lotion',
#  499: 'Sun Sensitive UV Face Sunscreen',
#  500: 'Hyaluronic Invisible Sunscreen Gel',
#  501: '1% Hyaluronic Acid SPF50 PA+++ Sunscreen Gel with Korean White Lotus',
#  502: 'Shadow Tinted SPF 50 PA+++ Sunscreen with Vitamin E & Hyaluronic Acid',
#  503: '1% Hyaluronic Tinted Sunscreen Gel for Broad Spectrum Protection',
#  504: 'Herbal Sun Guard SPF 60 PA++++ 3 In 1 Matte Lotion For UVA/UVB Protection',
#  505: 'SPF50 Sunscreen Stick Broad Spectrum PA++++ with Adenosine & Rice Bran Oil',
#  506: '7D Hydro Burst Hybrid Water Sunscreen SPF 50 PA +++, Hyaluronic & Coconut water',
#  507: 'Ginseng Moist Sun Serum SPF50+ PA++++',
#  508: 'Invisible Gel Oil Free SPF 50+ PA++++ Sunscreen',
#  509: 'Hydrate+ SPF 50 PA+++ Dewy Sunscreen For UVA/B & Blue Light Protection',
#  510: 'Intensive Long Lasting SPF 50 Sunscreen',
#  511: 'Beetroot Hydraful SPF 50 & PA++++ Sunscreen with Hyaluronic Acid',
#  512: 'Mineral Sports SPF 50+ PA+++ Sunscreen Gel',
#  513: 'AC SPF50 Hydrating Lightweight Non-Greasy & Non-Sticky Sunscreen PA++++',
#  514: 'Sun Shield Carrot 40+ SPF Ultra Protective Face Cream For Normal to Oily Skin',
#  515: 'Glow Surge Airy Sunstick SPF 50',
#  516: 'On-the-Go Strawberry Dew SPF 50 Sunscreen Stick',
#  517: 'Aqua Glow Hydrating SPF50 PA+ Sunscreen Gel With Himalayan Thermal Water',
#  518: 'Sunblock & Anti Tan SPF 40 PA+++ Sunscreen with Papaya & Saffron',
#  519: 'Set of 2 Sunscreen Fairness Liquorice UV Lotion, SPF 40 PA+++',
#  520: 'Unisex Cinnabloc Protective SPF 15 Sunscreen Lotion',
#  521: 'Ultra-Light SPF 50 PA+++ Indian Sunscreen with Carrot Seed & Turmeric',
#  522: 'Super UV Invisible Air-Mist Sunscreen SPF50 PA++++',
#  523: 'Unisex SPF50 Multiprotect Sun Lotion',
#  524: 'De Tan SPF 50 PA+++ Sunscreen Gel Cream For Sun Protection',
#  525: 'Ultra Matte Sunscreen SPF 50 PA++++ Lightweight & Water Resistant',
#  526: 'Kind to Skin Lightweight Matte Finish Gel Sunscreen SPF 50 PA++++',
#  527: 'Cica & Hyaluronic Acid Aqua Light Sunscreen SPF 50 PA+++',
#  528: 'Uniqaya Tinted Broad Spectrum Sun Protection Sunscreen with SPF 50, PA+++',
#  529: 'Sunscreen Matte Finish SPF 55 PA+++ for Very High Broad Spectrum',
#  530: 'Ultra Matte Dry Touch SPF50+ PA+++ Smooth Mousse Sunscreen',
#  531: '5 Barrier+ Repair Avocado & 5 Essential Ceramides Moisturizing Sunscreen',
#  532: 'Set of 3 Gulabari Rose Water with Aloevera Face Toner For Hydrated Skin',
#  533: '3% Niacinamide Alcohol-Free Toner With Rice Water To Reduce Pores & Blemishes',
#  534: 'Wonder Ceramide Mochi Toner',
#  535: 'Rice & Ceramide Moisturizing Toner for A Glowing Skin',
#  536: 'Cucumber Pore Tightening Normal to Oily Skin Refreshing Toner',
#  537: 'Heartleaf 77% Soothing Toner',
#  538: 'Premium Rose Water for All Skin Types',
#  539: 'AHA-BHA Clarifying Treatment Toner',
#  540: '3% PHA Alcohol Free Toner For Oily Skin',
#  541: 'Watermelon AHA Pore Tightening Toner with Glycolic for Glowing Skin',
#  542: 'Rice Water Hydrating Toner with Hyaluronic for Oily & Sensitive Skin',
#  543: '2-In-1 Cream Skin Cerapeptide Toner & Moisturizer Refiner For Hydration',
#  544: 'Bulgarian Valley Rose Water Spray Toner With Hyaluronic Acid To Hydrate Skin',
#  545: 'Ginseng Essence Mini with Ginseng & Niacinamide for Glow',
#  546: 'Transparent Clarifying Wonder Rice Smoothing Toner',
#  547: 'Green Tea Alcohol-Free Toner With Glycolic Acid To Tighten Pores & Fight Pimples',
#  548: 'Rice Water Dewy Face Toner With Rice Water 4% Niacinamide For Glass Skin',
#  549: 'Unisex Red Pure & Natural Kannauj Rose Water For Skin, Face & Hair',
#  550: 'Rose Glass Skin Mist',
#  551: 'AHA & BHA Clarifying Treatment Toner for Sensitive Skin Friendly',
#  552: 'Honey Water Pore Tightening & Brightening Toner',
#  553: 'Ginseng Essence Water with 80% Ginseng & Niacinamide Boost',
#  554: 'Cica Niacinamide Skin Clarifying Alcohol Free Toner',
#  555: 'Set of 3 Gulabari Premium Rose Water Face Toner For Hydrated Skin',
#  556: 'Green Tea Fresh Toner',
#  557: 'Supple Preparation Facial Toner with with Amino Acids & Centella',
#  558: 'Rose water',
#  559: 'Bulgarian Valley Rose Water Toner For Tightens Pores',
#  560: '9 to 5 Moist Matte Mattifying Face Toner with Green Tea',
#  561: 'Heartleaf 77% Clear Pad',
#  562: 'Green Tea Alcohol-Free Face Toner',
#  563: 'Centella Asiatic Extract',
#  564: 'AHA-BHA-PHA 30 Days Miracle Toner',
#  565: 'Transparent Hydrate Refresh Toning Mist',
#  566: 'Kind To Skin Soothing Facial Toner',
#  567: 'AHA-BHA-PHA 30 Days Miracle Toner for Pore Care',
#  568: 'Squalane Alcohol-Free Hydrating Face Toner & Mist',
#  569: 'The Dazzler Multivitamin Glow Toner & Makeup Setting Spray With Vitamin C',
#  570: 'Natural Ceramide with Rice Water & Licorice Extract Face Toner',
#  571: 'Advanced Organics Tea Tree Skin Clearing Mattifying Face Toner',
#  572: 'Set of 2 Steam Distilled Rose Water',
#  573: 'Niacinamide 10% Toner',
#  574: 'Essentials Daily Green Apple Glow Toner with Niacinamide',
#  575: 'Rose Skin Toner For Youthful Skin To Tighten Pores & Healthy Glow',
#  576: '1.5% Vitamin C Alcohol-Free Spray Toner With Mandarin & Witch Hazel For Glow',
#  577: 'Morning Nectar Visibly Flawless Pore Tightening & Purifying Toner',
#  578: 'Derma Skin Clear Toner with Salicylic Acid & Niacinamide',
#  579: 'Gulabari Premium Rose Water For Cleaner Hydrated & Moisturised Skin',
#  580: 'Vitamin C Face Toner for Glowing & Brightening Skin',
#  581: 'Salironic Toner with Hyaluronic Acid for Sensitive Skin',
#  582: 'Mandarin & Vitamin C Toner with Kakadu Plum',
#  583: 'Rose Water Skin Toner To Prevent Acne Pimples & Blackheads',
#  584: 'Skin Face Toner/Make up Remover Steam Distilled Rose Water',
#  585: 'Rose Water Face Toner & Mist',
#  586: '7% Glycolic Acid Hydrating Toner For Exfoliation',
#  587: 'Cucumber Skin Toner for Oily & Acne Prone Skin To Cleanse & Hydrate',
#  588: 'Tea Tree Purifying Alcohol-Free Toner To Cleanse, Refine & Tighten Pores',
#  589: 'Korean Supple Preparation Unscented Face Toner with Centella Asiatica',
#  590: 'Black Tea Youth Enhancing Skin Toner',
#  591: '100% Pure Fresh Distilled Rose Flora Jal Toner For Skin Toning',
#  592: 'Pomegranate & Collagen Volume Lifting Toner',
#  593: 'Vitamin C Face Toner with Vitamin C & Cucumber for Pore Tightening',
#  594: 'Niacin Face Toner with Niacinamide & Witch Hazel for Acne & Open Pores',
#  595: 'Dive In Low Molecular Hyaluronic Acid Toner',
#  596: 'Hyaluronic Acid Toner Plus',
#  597: 'Korean Vegan Supple Preparation Unscented Toner with with Amino Acids',
#  598: 'Green Plum Toner with Exfoliating AHA+BHA + Plum for Smooth Skin',
#  599: 'Green Tea Hyaluronic Mist',
#  600: 'Refresh AHA BHA Vitamin C Daily Toner with Kiwi & Dragon Fruit',
#  601: 'Gentle Exfoliating Face Toner with Glycolic & Niacinamide',
#  602: 'Refreshing & Clarifying Alcohol-Free Toner with Lentil & Citrus Lemon',
#  603: 'Skin Toner With Rose & Mint',
#  604: '10% Niacinamide Toner for Acne Marks, Blemishes & Oil Control',
#  605: 'Centella Water Alcohol-Free Toner for Sensitive Skin',
#  606: 'Skin Toner With Rose & Mint',
#  607: 'Rose Oil & Tea Tree Face Toner Mist',
#  608: 'Blossom Kochhar Aromatic Skin Toner For Oily Skin',
#  609: 'Vitamin C Radiant Glow Toner with Glycolic Acid & Vitamin B5',
#  610: 'Alcohol Free Hydrating Vitamin C Face Toner for All Skin Types',
#  611: 'Advanced Organics Clear Improvement Vitamin C Face Toner',
#  612: 'Hydro Distilled Edible Damask Rose Water Spray',
#  613: 'Skin Face Toner & Make up Remover Steam Distilled Rose Water',
#  614: 'Super Smooth 5% BHA Exfoliating Toner with Apricot & Fruit Enzyme',
#  615: 'White Seed Range Brightening Toner',
#  616: 'Pineapple Exfoliation Face Toner Hydrating Face Toner',
#  617: 'Classic Rose Toner',
#  618: 'Jamun Clarifying Fruity Toner With Niacinamide & Jamun Extract',
#  619: 'Chamomile White Tea Range Calming Antioxidant Toner',
#  620: 'Kumkumadi Toner with Rice Water For Glowing & Hydrating Skin',
#  621: 'Milk Peptide Face Toner',
#  622: 'Cucumber Pore Tightening Toner',
#  623: 'Dr V SkinRenew Peptide Hydrating Toner With Peptide & Hyaluronic Acid',
#  624: 'Daily Clarifying 2% BHA Exfoliating Toner with Tea Tree for Acne Prone Skin',
#  625: 'Unisex Collagen Nutrition Toner',
#  626: 'Set Of 2 White Lotus Natural Face Mist & Toner With Camellia',
#  627: 'Hyaluronic Acid Toner With Grape Seed Extract & Hyaluronic Acid',
#  628: 'Houttuynia Cordata Extract',
#  629: 'Steam Distilled Rose Water Spray Face Toner',
#  630: 'Set of 2 Rosetone Rose Petals Facial Toner',
#  631: 'Hydrium Watery Toner',
#  632: '100% Pure & Natural Rose Water Steam Distilled Face Spray Toner',
#  633: 'Hyaluronic Acid & Coffee Toner',
#  634: 'Sun Defense Neem Skin Toner',
#  635: 'Set of 2 Pure Gulab Flora Jal Toner Spray for Pore Reduction',
#  636: 'Classic Cucumber Toner',
#  637: 'Himalayan Rose Rose Water',
#  638: 'Set of 2 Pure & Natural Rose Water Face Toner For All Skin Types',
#  639: 'Pink Rose Water Toner with Vitamin E, Hyaluronic Acid & Aloe Vera',
#  640: 'Rose Water Toner Gulab Jal with Aloe Vera & 2% Niacinamide',
#  641: 'Pure Fit Cica Toner for Sensitive Skin',
#  642: 'Rose Face Toner with Witch Hazel & Rose Water for Pore Tightening',
#  643: 'AC Collection Acne Calming Liquid Intensive with AHA & BHA Toner for Acne',
#  644: 'Fruit AHA Mix & Green Tea Resurfacing Toner',
#  645: 'Black Rice Hyaluronic Toner',
#  646: 'Multipurpose Toning Solution',
#  647: 'Skin Defense Rose Water Toner For All Skin Types',
#  648: 'Premium and Natural Rose Water Spray Gulab Jal for Face',
#  649: 'Deep Sweep 2% BHA Pore Cleaning Toner with Moringa',
#  650: 'Hyaluronic Acid Complex Face Serum for Intense Hydration',
#  651: 'Set of 2 Rose Water Toner with Aloe Vera & 2% Niacinamide',
#  652: 'Yuzu Fine Vitamin C Brightening Toner For Glowing Skin With Orange Peel',
#  653: 'Set Of 3 100% Pure Fresh Distilled Rose Flora Jal Toner',
#  654: 'The Chok Chok Green Tea Watery Skin Toner',
#  655: 'Collagen Boosting Toner with Aloe Vera Extracts & Glycerin',
#  656: 'Clarifying & Pore Minimizing Green Tea Face Toner for All Skin Types',
#  657: 'Calendula Officinalis Flower Extract Toner for Sensitive Skin',
#  658: 'PHA 10% Gluconolactone Face Toner with Hyaluronic Acid',
#  659: 'Lavender & Rose Vegan Skin Mist Toner',
#  660: 'Set Of 2 Herbal Cucumber Skin Toner For Oily',
#  661: 'Dewy Rose Toner',
#  662: 'Co-earth Vitamin C Face Toner with Cucumber & Watermelon'}

# %%
# Checking missing values
print(data.isnull().sum())
# Out:
# product_brand        0
# product_name         0
# product_category     0
# quantity             0
# price                0
# overall_rating       0
# no_of_ratings        0
# concern              0
# ingredient           0
# skin_type            0
# star_5               0
# star_4               3
# star_3              35
# star_2              72
# star_1              34
# dtype: int64

# %%
# Fill missing star ratings with 0
star_columns = ['star_5', 'star_4', 'star_3', 'star_2', 'star_1']
data[star_columns] = data[star_columns].fillna(0)

# Verify changes
print("Missing values after filling:")
print(data[star_columns].isnull().sum())
# Out:
# Missing values after filling:
# star_5    0
# star_4    0
# star_3    0
# star_2    0
# star_1    0
# dtype: int64

# %%
# Checking for duplicate rows
print("\nDuplicate Rows Count:")
print(data.duplicated().sum())
# Out:
# Duplicate Rows Count:
# 0

# %%
# Calculate percentage of ratings for each star category
for col in star_columns:
    data[f"{col}_percentage"] = (data[col] / (data['no_of_ratings'])).fillna(0)

# Verify
print(data[[f"{col}_percentage" for col in star_columns]].head())
# Out:
#    star_5_percentage  star_4_percentage  star_3_percentage  star_2_percentage  \
# 0           0.720541           0.186809           0.048944           0.014918
# 1           0.770073           0.116788           0.041363           0.018248
# 2           0.693084           0.177204           0.059068           0.021075
# 3           0.647934           0.216529           0.080992           0.014876
# 4           0.665768           0.210243           0.063342           0.016173
#
#    star_1_percentage
# 0           0.028789
# 1           0.053528
# 2           0.049570
# 3           0.039669
# 4           0.044474

# %% [markdown]
# * Calculating percentages can help in analysis, as it allows comparison across products with different numbers of ratings.
#
#
# * Addition of 5 more columns namely star_5_percentage, star_4_percentage and so on increases shape of dataframe.

# %%
data.shape
# Out:
# (663, 20)

# %%
# Summary statistics
print("\nSummary Statistics:")
print(data.describe())
# Out:
# Summary Statistics:
#              price  overall_rating  no_of_ratings        star_5        star_4  \
# count   663.000000      663.000000     663.000000    663.000000    663.000000
# mean    471.286576        4.438763    4643.446456   3057.067873    969.389140
# std     352.134616        0.173091    8952.397853   5901.334426   1887.197458
# min      36.000000        2.900000       5.000000      3.000000      0.000000
# 25%     269.000000        4.400000     141.000000     98.000000     25.000000
# 50%     376.000000        4.400000     695.000000    472.000000    141.000000
# 75%     539.000000        4.500000    4040.000000   2724.500000    824.500000
# max    3712.000000        5.000000   55261.000000  37018.000000  11520.000000
#
#             star_3       star_2       star_1  star_5_percentage  \
# count   663.000000   663.000000   663.000000         663.000000
# mean    333.013575   105.571644   178.404223           0.675871
# std     654.793622   210.645685   337.739884           0.073883
# min       0.000000     0.000000     0.000000           0.375000
# 25%       8.000000     2.000000     5.000000           0.634146
# 50%      48.000000    14.000000    28.000000           0.666667
# 75%     308.000000    98.500000   163.000000           0.706992
# max    3815.000000  1247.000000  1955.000000           1.000000
#
#        star_4_percentage  star_3_percentage  star_2_percentage  \
# count         663.000000         663.000000         663.000000
# mean            0.195149           0.064598           0.021081
# std             0.050990           0.026534           0.013664
# min             0.000000           0.000000           0.000000
# 25%             0.179172           0.053108           0.014157
# 50%             0.202877           0.067295           0.020286
# 75%             0.217477           0.080000           0.027546
# max             0.500000           0.162791           0.125000
#
#        star_1_percentage
# count         663.000000
# mean            0.043301
# std             0.030774
# min             0.000000
# 25%             0.029448
# 50%             0.039216
# 75%             0.049881
# max             0.375000

# %%
categorical_columns = ['ingredient', 'concern', 'skin_type','product_category']

# %%
for col in categorical_columns:
    print(f"Unique values in {col}:")
    print(data[col].unique())
    print("\n")
# Out:
# Unique values in ingredient:
# ['Niacinamide' 'Rose' 'Gel' 'Amino Acids' 'Salicylic Acid' 'Seaweed'
#  'Coffee' 'Vitamin C' 'Vitamin c' 'Aloe Vera' 'Retinol' 'Tea Tree'
#  'Ceramides' 'Shea Butter' 'Hyaluronic Acid' 'Turmeric' 'Sandalwood'
#  'Glycerin' 'Centella Asiatica' 'Cruelty-Free' 'Vitamin E' 'Hydration'
#  'Vitamin B3' 'Green Tea' 'Witch Hazel' 'AHA' 'Papaya' 'Ceramide'
#  'Daisy Flower Extract' 'Saffron' 'Avocado' 'Kiwi Gel' 'Honey'
#  'Lemon Grass' 'Mint and Eucalyptus' 'Lemon' 'Amla' 'Dull Skin'
#  'kumkumadi' 'Glycolic Acid' 'Green Apple' 'Grapefruit' 'Orange'
#  'Liquorice Extract' 'Carrot' 'Ceramides ' 'Squalene' 'CICA Niacinamide'
#  'Almond' 'Vitamin C and ECream' 'Beetroot' 'Alpha Arbutin' 'Watermelon'
#  'Pomegranate' 'Cream' 'Milk' 'Peach' 'Snail Mucin' 'Cucumber' '24k Gold'
#  'Caffeine' 'Kojic Acid' 'Goat Milk' 'Vitamin C and E' 'Collagen'
#  'Ginseng' 'Peptides' 'Argan Oil' 'Azelaic Acid' 'Zinc Oxide'
#  'Cherry tomato' 'Titanium Dioxide' 'Liquid' 'Anti-Oxidants' 'Blueberry'
#  'Cica calming' 'Coconut' 'Non-Comedogenic' 'Sand 03' 'Neem' 'Strawberry'
#  'Olives' 'Jojoba' 'Chamomile White Tea' 'Melanostain' 'Carrot Juice'
#  'Rose Water' 'Heartleaf' 'AHA-BHA' 'PHA' 'Rice water' 'Cerapeptide'
#  'Rose water' 'Ginseng and niacinamide' 'Rice Water'
#  'Ginseng and Niacinamide' 'Amino acids ' 'Centella Asiatic' 'Witch Hasel'
#  'Squalane' 'Licorice extract ' 'Organic' 'Niacinamide ' 'Green apple'
#  'Nectar' 'Salicylic acid' 'Glycolic acid' 'Black Tea'
#  'Pomegranate and Collagen' 'Cucumber and Vitamin c' 'Amino acids'
#  'Green Plum' 'Rose and mint' 'Centella water' 'Rose oil and tea'
#  'Pomegranate Extract' 'Glycolic acid ' 'Apricot' 'White Seed' 'Pineapple'
#  'Classic Rose' 'Jamun' 'White Tea' 'Milk Peptide' 'Hyaluronic acid' 'BHA'
#  'Camelia' 'Houttuynia Cordata' 'Hydrium Watery' 'Hyaluronic Acid '
#  'Rose Water ' 'Centella Astiatica' 'BHA ' 'Aloe Vera ' 'Green Tea '
#  'Calendula' 'Lavender' 'Dewy Rose']
#
#
# Unique values in concern:
# ['Deep Nourishment' 'Dull Skin' 'Acne or Blemishes' 'Excess Oil'
#  'Pore Care' 'Deep Pore Clean' 'Anti-Ageing' 'Deep cleansing'
#  'Deep Cleansing' 'Anti-Pollution' 'Retinol' 'Pigmentation' 'Tan Removal'
#  'Hydrating' 'Brightening' 'Oil Control' 'Dark Spots' 'Skin Inflammation'
#  'Dryness' 'Hydration' 'Uneven Skin Tone' 'Dullness' 'Softening'
#  'Vitamin C and E' 'Sun Protection' 'Softening and Smoothening'
#  'Darks Spots & Pigmentation' 'Skin Brightening' 'Ageing Skin'
#  'Uneven Texture' 'Acne Prone Skin' 'Darks Spots Pigmentation' 'Glow'
#  'Detan' 'Pore Minimizing and Blurring' 'Firming'
#  'Blackheads and Whiteheads' 'Redness']
#
#
# Unique values in skin_type:
# ['Sensitive' 'Normal' 'Combination' 'Oily' 'Dry' 'Normal Skin' 'Liquid'
#  'Lotion']
#
#
# Unique values in product_category:
# ['Cleanser' 'Moisturizer' 'Serum' 'Sunscreen' 'Toner']

# %%
#remove extra spaces
for col in categorical_columns:
    data[col] = data[col].str.strip()

#make case uniform
for col in categorical_columns:
    data[col] = data[col].str.lower()  # Convert to lowercase
# Alternatively, for title case:
# data[col] = data[col].str.title()

# %%
#mapping
skin_type_mapping = {
    'liquid': 'combination',  # Correct typo
    'lotion': 'combination',
    'normal skin': 'normal',
}
data['skin_type'] = data['skin_type'].replace(skin_type_mapping)

ingredient_mapping = {
    # Standard Ingredients
    'niacinamide': 'niacinamide',
    'rose water': 'rosewater',
    'amino acids': 'aminoacids',
    'salicylic acid': 'salicylicacid',
    'seaweed': 'seaweed',
    'coffee': 'coffee',
    'vitamin c': 'vitaminc',
    'vitamin c and e': 'vitamincande',
    'vitamin c and ecream': 'vitamincande',
    'aloe vera': 'aloevera',
    'tea tree': 'teatree',
    'ceramides': 'ceramides',
    'ceramides and hyaluronic acid': 'ceramides',
    'shea butter': 'sheabutter',
    'hyaluronic acid': 'hyaluronicacid',
    'turmeric': 'turmeric',
    'sandalwood': 'sandalwood',
    'glycerin': 'glycerin',
    'centella asiatica': 'centellaasiatica',
    'centella asiatic': 'centellaasiatica',  # Fix typo
    'centella astiatica': 'centellaasiatica',  # Fix typo
    'centella water': 'centellaasiatica',
    'vitamin e': 'vitamine',
    'vitamin b3': 'vitaminb3',
    'green tea': 'greentea',
    'green tea face': 'greentea',
    'witch hazel': 'witchhazel',
    'witch hasel': 'witchhazel',  # Fix typo
    'aha': 'aha',
    'bha': 'bha',
    'aha-bha': 'ahabha',
    'pha': 'pha',
    'glycolic acid': 'glycolicacid',
    'alpha arbutin': 'alphaarbutin',
    'kojic acid': 'kojicacid',
    'azelaic acid': 'azelaicacid',
    'zinc oxide': 'zincoxide',
    'titanium dioxide': 'titaniumdioxide',
    'papaya': 'papaya',
    'daisy flower extract': 'daisyflowerextract',
    'saffron': 'saffron',
    'avocado': 'avocado',
    'kiwi gel': 'kiwi',
    'honey': 'honey',
    'lemon grass': 'lemongrass',
    'mint and eucalyptus': 'eucalyptus',
    'lemon': 'lemon',
    'amla': 'amla',
    'kumkumadi': 'kumkumadi',
    'green apple': 'greenapple',
    'grapefruit': 'grapefruit',
    'orange': 'orange',
    'liquorice extract': 'licoriceextract',
    'licorice extract': 'licoriceextract',
    'carrot': 'carrot',
    'carrot juice': 'carrot',
    'squalene': 'squalane',
    'squalane': 'squalane',
    'retinol': 'retinol',
    'almond': 'almond',
    'beetroot': 'beetroot',
    'watermelon': 'watermelon',
    'pomegranate': 'pomegranate',
    'pomegranate extract': 'pomegranate',
    'pomegranate and collagen': 'pomegranate',
    'milk': 'milk',
    'goat milk': 'milk',
    'milk peptide': 'peptides',
    'peach': 'peach',
    'snail mucin': 'snailmucin',
    'cucumber': 'cucumber',
    'cucumber and vitamin c': 'cucumber',
    '24k gold': 'gold',
    'caffeine': 'coffee',
    'collagen': 'collagen',
    'ginseng': 'ginseng',
    'ginseng and niacinamide': 'ginseng',
    'peptides': 'peptides',
    'argan oil': 'arganoil',
    'cherry tomato': 'cherrytomato',
    'blueberry': 'blueberry',
    'coconut': 'coconut',
    'neem': 'neem',
    'strawberry': 'strawberry',
    'olives': 'olives',
    'jojoba': 'jojoba',
    'chamomile white tea': 'chamomile',
    'melanostain': 'melanostain',
    'heartleaf': 'heartleaf',
    'rice water': 'ricewater',
    'rice water and niacinamide': 'niacinamide',
    'cerapeptide': 'peptides',
    'mandarin-vitamin': 'mandarin',
    'black tea': 'blacktea',
    'green plum': 'greenplum',
    'rose and mint': 'rosewater',
    'rose oil and tea': 'rosewater',
    'apricot': 'apricot',
    'white seed': 'whiteseed',
    'pineapple': 'pineapple',
    'jamun': 'jamun',
    'white tea': 'whitetea',
    'camelia': 'camellia',
    'houttuynia cordata': 'houttuyniacordata',
    'hydrium watery': 'hydriumwatery',
    'dewy rose': 'rosewater',
    'chamomile and white tea':'chamomile',
    'classic rose' :'rosewater',

    # Non-Specific Entries to Remove or Replace
    'dull skin': None,
    'gel': None,
    'hydration': None,
    'cruelty-free': None,
    'organic': None,
    'cream': None,
    'liquid': None,
    'cica calming': None,
    'non-comedogenic': None,
    'sand 03': None,
    'anti-oxidants': None
}
data['ingredient'] = data['ingredient'].replace(ingredient_mapping)
# Drop rows with None values
data = data[data['ingredient'].notnull()]

concern_mapping = {
    'deep nourishment': 'nourishment',
    'dull skin': 'dullness',
    'acne or blemishes': 'acne',
    'excess oil': 'oilcontrol',
    'pore care': 'porecare',
    'deep pore clean': 'deepcleansing',
    'anti-ageing': 'antiaging',
    'deep cleansing': 'deepcleansing',
    'deep cleansing': 'deepcleansing',
    'anti-pollution': 'antipollution',
    'retinol': None,
    'pigmentation': 'pigmentation',
    'tan removal': 'tanremoval',
    'hydrating': 'hydration',
    'brightening': 'brightening',
    'oil control': 'oilcontrol',
    'dark spots': 'darkspots',
    'skin inflammation': 'inflammation',
    'dryness': 'dryness',
    'hydration': 'hydration',
    'uneven skin tone': 'unevenskintone',
    'dullness': 'dullness',
    'softening': 'hydration',
    'vitamin c and e': None,
    'sun protection': 'sunprotection',
    'softening and smoothening': 'softening',
    'darks spots & pigmentation': 'darkspots',
    'skin brightening': 'brightening',
    'ageing skin': 'antiaging',
    'uneven texture': 'uneventexture',
    'acne prone skin': 'acne',
    'darks spots pigmentation': 'darkspots',
    'glow': 'glow',
    'detan': 'tanremoval',
    'pore minimizing and blurring': 'porecare',
    'firming': 'antiaging',
    'blackheads and whiteheads': 'blackheads',
    'redness': 'redness'
}
data['concern'] = data['concern'].replace(concern_mapping)

# Drop rows with None values
data = data[data['concern'].notnull()]
# Out:
# <ipython-input-18-67ad0b022d01>:177: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['concern'] = data['concern'].replace(concern_mapping)

# %%
data.shape
# Out:
# (646, 20)

# %%
for col in categorical_columns:
    print(f"Unique values in {col}:")
    print(data[col].unique())
    print("\n")
# Out:
# Unique values in ingredient:
# ['niacinamide' 'rose' 'aminoacids' 'salicylicacid' 'seaweed' 'coffee'
#  'vitaminc' 'aloevera' 'teatree' 'ceramides' 'sheabutter' 'hyaluronicacid'
#  'turmeric' 'sandalwood' 'glycerin' 'centellaasiatica' 'vitamine'
#  'vitaminb3' 'greentea' 'witchhazel' 'aha' 'papaya' 'ceramide'
#  'daisyflowerextract' 'saffron' 'avocado' 'kiwi' 'honey' 'lemongrass'
#  'eucalyptus' 'lemon' 'amla' 'kumkumadi' 'glycolicacid' 'greenapple'
#  'grapefruit' 'orange' 'licoriceextract' 'carrot' 'squalane' 'retinol'
#  'cica niacinamide' 'almond' 'vitamincande' 'beetroot' 'alphaarbutin'
#  'watermelon' 'pomegranate' 'milk' 'peach' 'snailmucin' 'cucumber' 'gold'
#  'kojicacid' 'collagen' 'ginseng' 'peptides' 'arganoil' 'azelaicacid'
#  'zincoxide' 'cherrytomato' 'titaniumdioxide' 'blueberry' 'coconut' 'neem'
#  'strawberry' 'olives' 'jojoba' 'chamomile' 'melanostain' 'rosewater'
#  'heartleaf' 'ahabha' 'pha' 'ricewater' 'nectar' 'blacktea' 'greenplum'
#  'apricot' 'whiteseed' 'pineapple' 'jamun' 'whitetea' 'bha' 'camellia'
#  'houttuyniacordata' 'hydriumwatery' 'calendula' 'lavender']
#
#
# Unique values in concern:
# ['nourishment' 'dullness' 'oilcontrol' 'porecare' 'acne' 'deepcleansing'
#  'antiaging' 'antipollution' 'pigmentation' 'tanremoval' 'hydration'
#  'brightening' 'darkspots' 'inflammation' 'dryness' 'unevenskintone'
#  'sunprotection' 'softening' 'uneventexture' 'glow' 'blackheads' 'redness']
#
#
# Unique values in skin_type:
# ['sensitive' 'combination' 'oily' 'normal' 'dry']
#
#
# Unique values in product_category:
# ['cleanser' 'moisturizer' 'serum' 'sunscreen' 'toner']

# %%
data.columns
# Out:
# Index(['product_brand', 'product_name', 'product_category', 'quantity',
#        'price', 'overall_rating', 'no_of_ratings', 'concern', 'ingredient',
#        'skin_type', 'star_5', 'star_4', 'star_3', 'star_2', 'star_1',
#        'star_5_percentage', 'star_4_percentage', 'star_3_percentage',
#        'star_2_percentage', 'star_1_percentage'],
#       dtype='object')

# %% [markdown]
# Label Encoding for 'product_category' and 'skin_type'

# %%
import pickle
with open('/content/drive/MyDrive/BlushBot/datasets/data.pkl', 'wb') as file:
    pickle.dump(data, file)

print("TF-IDF Vectorizer saved to tfidf_vectorizer.pkl")
# Out:
# TF-IDF Vectorizer saved to tfidf_vectorizer.pkl

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize label encoders
label_encoder_category = LabelEncoder()
label_encoder_skinType = LabelEncoder()

# Apply encoding to Product Category
data['Product Category Encoded'] = label_encoder_category.fit_transform(data['product_category'])

# Apply encoding to Skin Type
data['Skin Type Encoded'] = label_encoder_skinType.fit_transform(data['skin_type'])

# Check the mappings
print("Product Category Mapping:")
print(dict(zip(label_encoder_category.classes_, label_encoder_category.transform(label_encoder_category.classes_))))

print("\nSkin Type Mapping:")
print(dict(zip(label_encoder_skinType.classes_, label_encoder_skinType.transform(label_encoder_skinType.classes_))))
# Out:
# Product Category Mapping:
# {'cleanser': 0, 'moisturizer': 1, 'serum': 2, 'sunscreen': 3, 'toner': 4}
#
# Skin Type Mapping:
# {'combination': 0, 'dry': 1, 'normal': 2, 'oily': 3, 'sensitive': 4}

# %% [markdown]
# TF-IDF Vectorization for 'concern' and 'ingredient'

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_concern = TfidfVectorizer(max_features=50, stop_words='english')
tfidf_ingredient = TfidfVectorizer(max_features=50, stop_words='english')

concern_tfidf = tfidf_concern.fit_transform(data['concern']).toarray()
ingredient_tfidf = tfidf_ingredient.fit_transform(data['ingredient']).toarray()

# Combine TF-IDF features into DataFrames
concern_df = pd.DataFrame(concern_tfidf, columns=tfidf_concern.get_feature_names_out())
ingredient_df = pd.DataFrame(ingredient_tfidf, columns=tfidf_ingredient.get_feature_names_out())

# %%
import pickle

# Save both the TF-IDF matrix and the fitted vectorizer
with open('/content/drive/MyDrive/BlushBot/datasets/concern_tfidf.pkl', 'wb') as file:
    pickle.dump({
        'concern_tfidf': concern_tfidf,
        'tfidf_concern': tfidf_concern
    }, file)

# %%
'''import pickle
with open('/content/drive/MyDrive/BlushBot/datasets/concern_tfidf.pkl.pkl', 'wb') as file:
    pickle.dump(concern_tfidf, file)

print("TF-IDF Vectorizer saved to tfidf_vectorizer.pkl")
# Out:
# TF-IDF Vectorizer saved to tfidf_vectorizer.pkl

# %%
print(concern_df.shape)
print(ingredient_df.shape)

# %%
# Normalize price
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
data['Price Normalized'] = scaler.fit_transform(data[['price']])

# %%
print(data['Price Normalized'])

# %%
data.head()

# %%
for col in ['product_brand', 'product_name']:
    freq = data[col].value_counts() / len(data)
    data[f"{col}_encoded"] = data[col].map(freq)

print(data)

# %%
# prompt: make a dataframe of data to save

import pandas as pd

# Assuming 'data' DataFrame is already created from the previous code

# Select specific columns for the new DataFrame
columns_to_save = ['product_brand_encoded', 'product_name_encoded', 'product_category', 'skin_type', 'price', 'overall_rating', 'concern', 'ingredient', 'Product Category Encoded', 'Skin Type Encoded', 'Price Normalized']
data_to_save = data[columns_to_save]

# Display the new DataFrame (optional)
print(data_to_save.head())

# %%
columns_to_combine = [
    'star_5_percentage', 'star_4_percentage', 'star_3_percentage', 'star_2_percentage', 'star_1_percentage','Price Normalized',
     'Product Category Encoded', 'Skin Type Encoded',	'product_brand_encoded','product_name_encoded']

# %%
final_combined = data[columns_to_combine]
final_combined.head()

# %%
model_df = pd.concat([final_combined, concern_df, ingredient_df], axis=1)
model_df.head()

# %%
model_df.shape

# %%
# Filling all the Nan values in model_df with 0
model_df.fillna(0, inplace=True)

# %%
# Save the combined DataFrame to a CSV file
model_df.to_csv('/content/drive/MyDrive/BlushBot/datasets/combined_encoded_data.csv', index=False)

# %%
from sklearn.metrics.pairwise import cosine_similarity
cosine_sim = cosine_similarity(model_df)

# %%
# Function to encode user input based on the mappings
def encode_user_inputs(user_skin_type, user_category, user_price, data):
    # Encoding for Skin Type and Product Category
    skin_type_mapping = {'combination': 0, 'dry': 1, 'normal': 2, 'oily': 3, 'sensitive': 4}
    category_mapping = {'cleanser': 0, 'moisturizer': 1, 'serum': 2, 'sunscreen': 3, 'toner': 4}
    skin_type_encoded = skin_type_mapping.get(user_skin_type.lower(), None)
    category_encoded = category_mapping.get(user_category.lower(), None)

    if skin_type_encoded is None or category_encoded is None:
        return None  # Invalid input

    # Normalize user price based on the data's normalized price range
    price_normalized = (user_price - data['price'].min()) / (data['price'].max() - data['price'].min())

    return skin_type_encoded, category_encoded, price_normalized

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Predefined concerns in the data (example, adjust based on your dataset)
all_concerns = data['concern'].unique()  # All unique concerns in the dataset

# Fit TF-IDF Vectorizer
tfidf_vectorizer = TfidfVectorizer(stop_words='english')
concern_tfidf = tfidf_vectorizer.fit_transform(all_concerns)

# Function to vectorize user's concern and compare with existing concerns
def vectorize_user_concern(user_concern, tfidf_vectorizer):
    user_concern.strip().lower()
    user_concern_vec = tfidf_vectorizer.transform([user_concern])  # Vectorize user input
    return user_concern_vec

# %%
import pickle
with open('/content/drive/MyDrive/BlushBot/datasets/tfidf_vectorizer.pkl', 'wb') as file:
    pickle.dump(concern_tfidf, file)

print("TF-IDF Vectorizer saved to tfidf_vectorizer.pkl")

# %%
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

def recommend_filtered_products(user_skin_type, user_category, user_price, user_concern, data, tfidf_vectorizer, top_n=5, weight1=0.5, weight2=0.3, weight3=0.2, sigma=100):
    """
    Recommend products based on user inputs, star percentages, and price conditions, with price balance.

    Parameters:
    - user_skin_type (str): Skin type (non-encoded).
    - user_category (str): Product category (non-encoded).
    - user_price (float): User's price range.
    - user_concern (str): Skin concern (already preprocessed).
    - data (DataFrame): Original dataset.
    - tfidf_vectorizer: Pre-trained TF-IDF vectorizer for 'concern'.
    - top_n (int): Number of top recommendations to return.
    - weight1 (float): Weight for cosine similarity in final ranking.
    - weight2 (float): Weight for 5-star percentage in final ranking.
    - weight3 (float): Weight for price score in final ranking.
    - sigma (float): Standard deviation for price proximity score.

    Returns:
    - DataFrame with top recommended products.
    """
    # Step 1: Encode user inputs
    encoded_inputs = encode_user_inputs(user_skin_type, user_category, user_price, data)

    if encoded_inputs is None:
        return "Invalid input provided."

    skin_type_encoded, category_encoded, price_normalized = encoded_inputs

    # Step 2: Filter products based on user inputs (skin type, category, and price conditions)
    filtered_data = data[
        (data['Skin Type Encoded'] == skin_type_encoded) &
        (data['Product Category Encoded'] == category_encoded) &
        ((data['price'] <= user_price + 150) | (data['price'] >= user_price - 150))  # Price condition
    ].copy()  # Explicitly create a copy to avoid chained assignment warnings

    if filtered_data.empty:
        return "No products match your filters"

    # Step 3: Vectorize the user's concern and compute cosine similarity with filtered products
    user_concern_vec = vectorize_user_concern(user_concern, tfidf_vectorizer)
    product_concerns = tfidf_vectorizer.transform(filtered_data['concern'])  # Vectorize product concerns
    similarity_scores = cosine_similarity(user_concern_vec, product_concerns).flatten()
    filtered_data['similarity_score'] = similarity_scores

    # Step 4: Compute price proximity score
    filtered_data['price_score'] = np.exp(-((filtered_data['price'] - user_price) ** 2) / (2 * sigma ** 2))

    # Step 5: Compute final ranking score
    filtered_data['similarity_score'] = similarity_scores
    filtered_data['final_score'] = (
        (filtered_data['similarity_score'] * weight1) +
        (filtered_data['star_5_percentage'] * weight2) +
        (filtered_data['price_score'] * weight3)
    )

    # Step 6: Sort by final score and select top N
    filtered_data = filtered_data.sort_values(by='final_score', ascending=False).head(top_n)

    # Return top N recommended products with details
    return filtered_data[['product_name', 'product_brand','product_category', 'price', 'skin_type', 'concern', 'star_5_percentage', 'final_score']]

# %%
# Example user inputs
user_skin_type = "combination"
user_category = "cleanser"
user_price = 250
user_concern = "hydration"

# Get recommendations
recommended_products = recommend_filtered_products(
    user_skin_type=user_skin_type,
    user_category=user_category,
    user_price=user_price,
    user_concern=user_concern,
    data=data,
    tfidf_vectorizer=tfidf_vectorizer,
    top_n=5
)

# Display recommendations
print("Top Recommended Products:")
print(recommended_products)

# %%
test_case_1 = {
    'user_skin_type': 'oily',
    'user_category': 'moisturizer',
    'user_price': 400,
    'user_concern': 'oilcontrol',
    'relevant_products': [
        'Sustainable Naked & Raw Coffee Face Moisturizer',
        'Oil-Free Gel Face Moisturizer',
        '100% Natural Salicylic Acid Liquid Moisturiser with Aloevera & Zinc PCA',
        '5% Nia-Ceramide Mattifying Moisturizer for Oil Control',
        'Strawberry Dew Do-It-All Moisturizer'
    ]
}

test_case_2 = {
    'user_skin_type': 'dry',
    'user_category': 'serum',
    'user_price': 800,
    'user_concern': 'antiaging',
    'relevant_products': [
        'Regenerist Micro Sculpting Serum with Hyaluronic Acid',
        'Retinol24 Max Night Serum To Visibly Reduce Fine Lines',
        '24K Gold Serum with Niacinamide & Hyaluronic Acid',
        'Dandelion Youth Anti-Ageing Serum',
        '2% Salicylic Acid Serum With Witch Hazel'
    ]
}

test_case_3 = {
    'user_skin_type': 'sensitive',
    'user_category': 'sunscreen',
    'user_price': 600,
    'user_concern': 'sunprotection',
    'relevant_products': [
        'C-Cinamide Sunscreen SPF 50 PA+ Aqua Gel With Vitamin C & Niacinamide',
        'SPF 50++ Relief Sun Rice Probiotics',
        'Relief Sun',
        'Sun Sensitive UV Face Sunscreen',
        'Sun SPF30 Light Gel with Vitamin E'
    ]
}

test_case_4 = {
    'user_skin_type': 'combination',
    'user_category': 'cleanser',
    'user_price': 250,
    'user_concern': 'hydration',
    'relevant_products': [
        'Restore Hydrating Cream Cleanser',
        '2% Vitamin C Face Wash Foaming Cleanser with Brush',
        'The Daily Duet Gentle Hydrating Cleanser',
        'Clarifying Acne Cleanser with Zinc PCA & Salicylic Acid',
        'Total Effects Foaming Cleanser & Face Wash To Fight 7 Signs of Ageing'
    ]
}

test_case_5 = {
    'user_skin_type': 'normal',
    'user_category': 'toner',
    'user_price': 1500,
    'user_concern': 'darkspots',
    'relevant_products': [
        'Houttuynia Cordata Extract',
        '1.5% Vitamin C Alcohol-Free Spray Toner With Moisture',
        'Heartleaf 77% Soothing Toner',
        'Wonder Ceramide Mochi Toner',
        'White Seed Range Brightening Toner'
    ]
}


test_cases = [test_case_1, test_case_2,test_case_3,test_case_4,test_case_5]

# %%
# Precision at K
def calculate_precision_at_k(recommended_products, relevant_products, k):
    # Get the top k recommendations (assuming recommended_products is a DataFrame)
    top_k_recommendations = recommended_products['product_name'][:k].tolist()
    relevant_count = len(set(top_k_recommendations) & set(relevant_products))  # Find common products
    return relevant_count / k

# Recall at K
def calculate_recall_at_k(recommended_products, relevant_products, k):
    # Get the top k recommendations (assuming recommended_products is a DataFrame)
    top_k_recommendations = recommended_products['product_name'][:k].tolist()
    relevant_count = len(set(top_k_recommendations) & set(relevant_products))  # Find common products
    return relevant_count / len(relevant_products)  # Recall is based on the relevant products

# %%
# Evaluate the model
results = []

for test in test_cases:
    # Generate recommendations
    recommended_products = recommend_filtered_products(
        user_skin_type=test['user_skin_type'],
        user_category=test['user_category'],
        user_price=test['user_price'],
        user_concern=test['user_concern'],
        data=data,
        tfidf_vectorizer=tfidf_vectorizer,
        top_n=5
    )

    # Calculate Precision and Recall at K
    precision = calculate_precision_at_k(recommended_products, test['relevant_products'], k=5)
    recall = calculate_recall_at_k(recommended_products, test['relevant_products'], k=5)

    results.append({'Test Case': test, 'Precision@5': precision, 'Recall@5': recall})

# Display results
for idx, result in enumerate(results, start=1):
    print(f"Test Case {idx}:")
    print(f"User Input: {result['Test Case']}")
    print(f"Precision@5: {result['Precision@5']:.2f}")
    print(f"Recall@5: {result['Recall@5']:.2f}\n")

# %%
# Calculate average Precision and Recall
avg_precision = sum(result['Precision@5'] for result in results) / len(results)
avg_recall = sum(result['Recall@5'] for result in results) / len(results)

print(f"Average Precision@5: {avg_precision:.2f}")
print(f"Average Recall@5: {avg_recall:.2f}")

# %%
model_df['Product Category Encoded'].values

# %%
data.to_dict()
pickle.dump(data.to_dict(), open('/content/drive/MyDrive/BlushBot/datasets/data_df.pkl','wb'))

# %%
data['Skin Type Encoded'].values

# %% [markdown]
# #Frontend

# %%
# !pip install streamlit

# %%
import streamlit as st
import pandas as pd
import pickle
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# Load your data and models
with open('data.pkl', 'wb') as file:
    pickle.dump(data, file)
with open('model_df.pkl', 'wb') as file:
    pickle.dump(model_df,file)
with open('tfidf_vectorizer.pkl', 'wb') as file:
    pickle.dump(tfidf_vectorizer,file)

# %%
# Load Pickle files
with open('data.pkl', 'rb') as file:
    data = pickle.load(file)

with open('model_df.pkl', 'rb') as file:
    model_df = pickle.load(file)

with open('tfidf_vectorizer.pkl', 'rb') as file:
    tfidf_vectorizer = pickle.load(file)

'''# Define your functions (ensure these are imported or included)
def encode_user_inputs(user_skin_type, user_category, user_price, model_df):
    # Example encoding logic
    skin_type_mapping = {'oily': 0, 'dry': 1, 'sensitive': 2, 'combination': 3, 'normal': 4}
    category_mapping = {'moisturizer': 0, 'serum': 1, 'sunscreen': 2, 'cleanser': 3, 'toner': 4}

    if user_skin_type not in skin_type_mapping or user_category not in category_mapping:
        return None  # Invalid input

    skin_type_encoded = skin_type_mapping[user_skin_type]
    category_encoded = category_mapping[user_category]
    price_normalized = (user_price - model_df['price'].min()) / (model_df['price'].max() - model_df['price'].min())

    return skin_type_encoded, category_encoded, price_normalized


def recommend_filtered_products(user_skin_type, user_category, user_price, user_concern, data, model_df, top_n=5):
    encoded_inputs = encode_user_inputs(user_skin_type, user_category, user_price, model_df)
    if encoded_inputs is None:
        return "Invalid input provided."

    skin_type_encoded, category_encoded, price_normalized = encoded_inputs

    # Filter products based on model_df
    filtered_model_df = model_df[
        (model_df['Skin Type Encoded'] == skin_type_encoded) &
        (model_df['Product Category Encoded'] == category_encoded) &
        ((model_df['price_normalized'] <= price_normalized + 0.1) &
         (model_df['price_normalized'] >= price_normalized - 0.1))
    ].copy()

    if filtered_model_df.empty:
        return "No products match your filters"

    # Merge filtered data with user-facing attributes
    filtered_data = pd.merge(data, filtered_model_df, on='product_id')

    # Sort by final_score and return top N
    filtered_data = filtered_data.sort_values(by='final_score', ascending=False).head(top_n)

    return filtered_data[['product_name', 'product_brand', 'product_category', 'price', 'skin_type', 'concern', 'star_5_percentage', 'final_score']]
'''

# Streamlit App
st.title("Personalized Skincare Recommendation System")

# User Input Section
skin_type = st.selectbox("Select your skin type", ['oily', 'dry', 'sensitive', 'combination', 'normal'])
category = st.selectbox("Select product category", ['moisturizer', 'serum', 'sunscreen', 'cleanser', 'toner'])
concern = st.text_input("Enter your skin concern", "hydration")
price = st.number_input("Enter your price range (INR)", min_value=0, max_value=5000, value=500)

# Recommendation Button
if st.button("Get Recommendations"):
    recommendations = recommend_filtered_products(
        user_skin_type=skin_type,
        user_category=category,
        user_price=price,
        user_concern=concern,
        data=data,
        model_df=model_df,
        top_n=5
    )

    if isinstance(recommendations, str):
        st.write(recommendations)
    else:
        st.write("Top Recommended Products:")
        for _, row in recommendations.iterrows():
            st.write(f"**{row['product_name']}** by {row['product_brand']} - ₹{row['price']} ({row['concern']})")
